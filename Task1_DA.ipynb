# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df=pd.read_csv("/content/netflix_titles.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5351 entries, 0 to 5350
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5351 non-null   object
#  1   type          5351 non-null   object
#  2   title         5351 non-null   object
#  3   director      5351 non-null   object
#  4   cast          5351 non-null   object
#  5   country       5351 non-null   object
#  6   date_added    5351 non-null   object
#  7   release_year  5351 non-null   object
#  8   rating        5351 non-null   object
#  9   duration      5351 non-null   object
#  10  listed_in     5350 non-null   object
#  11  description   5334 non-null   object
# dtypes: object(12)
# memory usage: 501.8+ KB

# %%
df.isnull().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added       0
# release_year     0
# rating           0
# duration         0
# listed_in        1
# description     17
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5351 entries, 0 to 5350
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5351 non-null   object
#  1   type          5351 non-null   object
#  2   title         5351 non-null   object
#  3   director      5351 non-null   object
#  4   cast          5351 non-null   object
#  5   country       5351 non-null   object
#  6   date_added    5351 non-null   object
#  7   release_year  5351 non-null   object
#  8   rating        5351 non-null   object
#  9   duration      5351 non-null   object
#  10  listed_in     5350 non-null   object
#  11  description   5334 non-null   object
# dtypes: object(12)
# memory usage: 501.8+ KB

# %%
df.drop_duplicates()
# Out:
#      show_id     type                          title             director  \
# 0         s8    Movie                        Sankofa         Haile Gerima
# 1         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 2        s10    Movie                   The Starling       Theodore Melfi
# 3        s13    Movie                   Je Suis Karl  Christian Schwochow
# 4        s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 5346   s8805    Movie                     Zombieland      Ruben Fleischer
# 5347   s8806    Movie                           Zoom         Peter Hewitt
# 5348   s8807    Movie                         Zubaan          Mozez Singh
# 5349   s8808  TV Show             Parasyte: The Grey         Yeon Sang-ho
# 5350   s8809    Movie                         Serena         Susanne Bier
#
#                                                    cast  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5351 entries, 0 to 5350
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5351 non-null   object
#  1   type          5351 non-null   object
#  2   title         5351 non-null   object
#  3   director      5351 non-null   object
#  4   cast          5351 non-null   object
#  5   country       5351 non-null   object
#  6   date_added    5351 non-null   object
#  7   release_year  5351 non-null   object
#  8   rating        5351 non-null   object
#  9   duration      5351 non-null   object
#  10  listed_in     5350 non-null   object
#  11  description   5334 non-null   object
# dtypes: object(12)
# memory usage: 501.8+ KB

# %%
df.head(5)
# Out:
#   show_id     type                          title             director  \
# 0      s8    Movie                        Sankofa         Haile Gerima
# 1      s9  TV Show  The Great British Baking Show      Andy Devonshire
# 2     s10    Movie                   The Starling       Theodore Melfi
# 3     s13    Movie                   Je Suis Karl  Christian Schwochow
# 4     s25    Movie                          Jeans           S. Shankar
#
#                                                 cast  \
# 0  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 1  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 2  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 3  Luna Wedler, Jannis Niew̦hner, Milan Peschel,...
# 4  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
#
#                                              country date_added release_year  \
# 0  United States, Ghana, Burkina Faso, United Kin...  24-Sep-21         1993
# ...

# %%
df.dropna()
# Out:
#      show_id     type                          title             director  \
# 0         s8    Movie                        Sankofa         Haile Gerima
# 1         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 2        s10    Movie                   The Starling       Theodore Melfi
# 3        s13    Movie                   Je Suis Karl  Christian Schwochow
# 4        s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 5346   s8805    Movie                     Zombieland      Ruben Fleischer
# 5347   s8806    Movie                           Zoom         Peter Hewitt
# 5348   s8807    Movie                         Zubaan          Mozez Singh
# 5349   s8808  TV Show             Parasyte: The Grey         Yeon Sang-ho
# 5350   s8809    Movie                         Serena         Susanne Bier
#
#                                                    cast  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5334 entries, 0 to 5350
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5334 non-null   object
#  1   type          5334 non-null   object
#  2   title         5334 non-null   object
#  3   director      5334 non-null   object
#  4   cast          5334 non-null   object
#  5   country       5334 non-null   object
#  6   date_added    5334 non-null   object
#  7   release_year  5334 non-null   object
#  8   rating        5334 non-null   object
#  9   duration      5334 non-null   object
#  10  listed_in     5334 non-null   object
#  11  description   5334 non-null   object
# dtypes: object(12)
# memory usage: 670.8+ KB

# %%
df.drop_duplicates()
# Out:
#      show_id     type                          title             director  \
# 0         s8    Movie                        Sankofa         Haile Gerima
# 1         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 2        s10    Movie                   The Starling       Theodore Melfi
# 3        s13    Movie                   Je Suis Karl  Christian Schwochow
# 4        s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 5346   s8805    Movie                     Zombieland      Ruben Fleischer
# 5347   s8806    Movie                           Zoom         Peter Hewitt
# 5348   s8807    Movie                         Zubaan          Mozez Singh
# 5349   s8808  TV Show             Parasyte: The Grey         Yeon Sang-ho
# 5350   s8809    Movie                         Serena         Susanne Bier
#
#                                                    cast  \
# ...

# %%
df['date_added'] = pd.to_datetime(df['date_added'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5334 entries, 0 to 5350
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5334 non-null   object
#  1   type          5334 non-null   object
#  2   title         5334 non-null   object
#  3   director      5334 non-null   object
#  4   cast          5334 non-null   object
#  5   country       5334 non-null   object
#  6   date_added    5334 non-null   datetime64[ns]
#  7   release_year  5334 non-null   object
#  8   rating        5334 non-null   object
#  9   duration      5334 non-null   object
#  10  listed_in     5334 non-null   object
#  11  description   5334 non-null   object
# dtypes: datetime64[ns](1), object(11)
# memory usage: 670.8+ KB

# %%
df['release_year'] = df['release_year'].astype(int)

# %%
text_cols = ['type','title','director','cast','country','rating','listed_in']
for col in text_cols:
    df[col] = df[col].str.strip().str.lower()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5334 entries, 0 to 5350
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5334 non-null   object
#  1   type          5334 non-null   object
#  2   title         5334 non-null   object
#  3   director      5334 non-null   object
#  4   cast          5334 non-null   object
#  5   country       5334 non-null   object
#  6   date_added    5334 non-null   datetime64[ns]
#  7   release_year  5334 non-null   int64
#  8   rating        5334 non-null   object
#  9   duration      5334 non-null   object
#  10  listed_in     5334 non-null   object
#  11  description   5334 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 670.8+ KB

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5334 entries, 0 to 5350
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5334 non-null   object
#  1   type          5334 non-null   object
#  2   title         5334 non-null   object
#  3   director      5334 non-null   object
#  4   cast          5334 non-null   object
#  5   country       5334 non-null   object
#  6   date_added    5334 non-null   datetime64[ns]
#  7   release_year  5334 non-null   int64
#  8   rating        5334 non-null   object
#  9   duration      5334 non-null   object
#  10  listed_in     5334 non-null   object
#  11  description   5334 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 670.8+ KB

# %%
df['title'].apply(type).value_counts()
df['country'].apply(type).value_counts()
df['cast'].apply(type).value_counts()
# Out:
# cast
# <class 'str'>    5334
# Name: count, dtype: int64

# %%
df['title'] = df['title'].astype(str)
df['country'] = df['country'].astype(str)
df['cast'] = df['cast'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5334 entries, 0 to 5350
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5334 non-null   object
#  1   type          5334 non-null   object
#  2   title         5334 non-null   object
#  3   director      5334 non-null   object
#  4   cast          5334 non-null   object
#  5   country       5334 non-null   object
#  6   date_added    5334 non-null   datetime64[ns]
#  7   release_year  5334 non-null   int64
#  8   rating        5334 non-null   object
#  9   duration      5334 non-null   object
#  10  listed_in     5334 non-null   object
#  11  description   5334 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 670.8+ KB

# %%
df = df[df['title'].str.contains('[a-zA-Z]', na=False)]
df = df[df['country'].str.contains('[a-zA-Z]', na=False)]
df = df[df['cast'].str.contains('[a-zA-Z]', na=False)]

# %%
df['title'] = df['title'].str.strip()
df['country'] = df['country'].str.strip()
df['cast'] = df['cast'].str.strip()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5314 entries, 0 to 5350
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5314 non-null   object
#  1   type          5314 non-null   object
#  2   title         5314 non-null   object
#  3   director      5314 non-null   object
#  4   cast          5314 non-null   object
#  5   country       5314 non-null   object
#  6   date_added    5314 non-null   datetime64[ns]
#  7   release_year  5314 non-null   int64
#  8   rating        5314 non-null   object
#  9   duration      5314 non-null   object
#  10  listed_in     5314 non-null   object
#  11  description   5314 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 539.7+ KB

# %%
data=pd.read_csv("/content/cleaned_netflix_titles .csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5306 entries, 0 to 5305
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5306 non-null   object
#  1   type          5306 non-null   object
#  2   title         5306 non-null   object
#  3   director      5306 non-null   object
#  4   cast          5306 non-null   object
#  5   country       5306 non-null   object
#  6   date_added    5306 non-null   object
#  7   release_year  5306 non-null   int64
#  8   rating        5306 non-null   object
#  9   duration      5306 non-null   object
#  10  listed_in     5306 non-null   object
#  11  description   5306 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 497.6+ KB
